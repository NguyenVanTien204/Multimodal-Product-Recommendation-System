# %%
import pandas as pd

# %%
df = pd.read_parquet("data/items.parquet")
df_user = pd.read_parquet("data/train.parquet")
df.head(10)
# Out:
#       item_id                                              title  \
# 0  B085RX192V                        Crocs Women’s Freesail Clog
# 1  B078J3FZ12  BEARPAW Women's Boshie Multiple Colors | Women...
# 2  B07VKPPCNP  Scrubs for Women Workwear Professionals V-Neck...
# 3  B07BZCPRWC  Free to Live 3 Pack Womens Long, Loose Fitting...
# 4  B07H253XTD  Ginjang Women Winter Snow Boots Warm Ankle Boo...
# 5  B0BHDBDL7H  Hanes Women's Crewneck Sweatshirt, EcoSmart Fl...
# 6  B09R1PZC6K  Holipick Two Piece Swim Dress for Women Swimdr...
# 7  B098Y68NJV                        New Balance Women's Sneaker
# 8  B07QTVKNNQ  Dickies Men's Dri-tech Moisture Control Crew S...
# 9  B07BNS1JCF  DEARCASE Women's Long Sleeve Maxi Dress Crewne...
#
#                                          description  \
# 0  Elegant floral graphics croslite foam construc...
# 1
# 2
# 3
# 4
# 5  Stay comfy on the go with our unbelievably sof...
# 6
# 7  We stand for something bigger than sneakers. W...
# ...

# %%
df_user.head(10)
# Out:
#                         user_id     item_id  rating      timestamp  \
# 0  AE22CUYKCASNE3FV6MTCG7AIQFSA  B019VM3CPW     5.0  1470875333000
# 1  AE22CUYKCASNE3FV6MTCG7AIQFSA  B079GB72Q1     5.0  1537139381412
# 2  AE22CUYKCASNE3FV6MTCG7AIQFSA  B014L0J1PE     5.0  1537139459544
# 3  AE22CUYKCASNE3FV6MTCG7AIQFSA  B09ZQ5G8D7     5.0  1554554871099
# 4  AE22CUYKCASNE3FV6MTCG7AIQFSA  B0BGH8XQF6     5.0  1563065459823
# 5  AE22CUYKCASNE3FV6MTCG7AIQFSA  B083R4YZCJ     5.0  1563477940958
# 6  AE22CUYKCASNE3FV6MTCG7AIQFSA  B08KVDRG5V     5.0  1594002546503
# 7  AE22CUYKCASNE3FV6MTCG7AIQFSA  B078T87H8D     5.0  1614364470457
# 8  AE22E26NYX7FQGYKAGJY4OUORTMA  B004HI2E6Y     4.0  1386016464000
# 9  AE22E26NYX7FQGYKAGJY4OUORTMA  B0922DBSLN     5.0  1507907860367
#
#    verified_purchase
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# 5               True
# 6               True
# 7               True
# 8               True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31368 entries, 0 to 31367
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   item_id      31368 non-null  object
#  1   title        31368 non-null  object
#  2   description  31368 non-null  object
#  3   features     31368 non-null  object
#  4   category     31368 non-null  object
#  5   brand        31306 non-null  object
#  6   price        26566 non-null  float64
#  7   image_url    31361 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 1.9+ MB
